# %%
class treenode:
    def __init__(self, data):
        self.left = None
        self.right = None
        
        self.data = data


class bstdynamic:
    def __init__(self):
        self.root = None
        
        
        
    def insert(self, item):
        
        
        
        if self.root == None:
            self.root = treenode(item)
            return True
            
            
        else:
                
            current = self.root
            prev = None
            Left = True

            while current != None: # will either stop on None or an item that is bigger than the item
                prev = current


                if current.data > item:
                    #left is less, right is more

                    current = current.left
                    Left = True


                else:
                    current = current.right
                    Left = False
                    
                    
            #inserting
            
            if Left == True:
                prev.left = treenode(item)
                
            else:
                prev.right = treenode(item)
                
            return True

        

            #depth first searches / display
    def inorder(self, node):
        if self.root == None:
            return False
        
        
        if node == None:
            return
        
        self.inorder(node.left)
        print(node.data)
        self.inorder(node.right)
        
        
        
#Breadth‑First Traversal (BFS) as a level‑order traversal that visits nodes according to how far away they are from the root.
        
#Breadth‑first traversal (BFS) visits node according to how far away from the root (i.e.: traverse by level).”
    
        
        
        
        
        
        
    def preorder(self, node):   
        if self.root == None:
            return False
        
        
        if node == None:
            return
        
        print(node.data)
        self.preorder(node.left)
        self.preorder(node.right)
        
        
        
    def postorder(self, node):   
        
        if self.root == None:
            return False
        
        if node == None:
            return
        
        self.postorder(node.left)
        self.postorder(node.right)
        
        print(node.data)
        
        
        
    def breadthfirstsearch(self, node):
        if self.root is None:
            return

        queue = [self.root]   # start with root

        while queue:
            current = queue.pop(0)   # dequeue front
            print(current.data)

            if current.left:
                queue.append(current.left)
            if current.right:
                queue.append(current.right)
