# %%
#task 1.1, Qqueue using a linked list, insert at the back and delete at the front

def task1_1(input_value):
    try:
        check = input_value / 3 #if its a string this wont work
        
        if len(str(input_value)) != 14:
            return -1 
        
        input_value = str(input_value)
        
        
    except:
        
    
    
        if input_value.isdigit() == False:
            return -1



        if len(input_value) != 14:
            return -1
        
     
        
        
        
        
    value = 0
    count = 0
    for i in input_value:
        #
        #print(i)
        
        
        if count % 2 != 0: #means odd
            number = int(i) * 2
            
            if number >= 10:
                a, b = str(number)[0], str(number)[1]
                number = int(a) + int(b)
            
            value = value + number
            
        else:
            number = int(i)
            value = value + number
            
        #
        #print('number' + str(number))
        
        
        count += 1
    #print(value)
    checkdigit = 10 - ( value % 10)
    
    
    return checkdigit


#print(task1_1('14576567654935'))

# %%
#task 1.2
print(task1_1(14576567654935) == 9)
print(task1_1('14576567654935') == 9)
print(task1_1('1457656b654935') == -1)
print(task1_1(145765676549341) == -1)
# Out:
# True
# True
# True
# True

# %%
#task 1.3

def task1_3(input_value):
    try:
        check = input_value / 3
        
        input_value = str(input_value)
        
    except:
        if input_value.isdigit() == False:
            return False
        
        
        
    if len(input_value) != 15:
        return False
    
    
    #done validating
    
    checkdigit = input_value[-1]
    
    digits = input_value[:-1]
    
    #test
    #print()
    #print(checkdigit)
    #print(digits)
    
    
    checkdigit_generated = task1_1(digits)
    
    #print(checkdigit_generated)
    #print()
    
    if checkdigit_generated == int(checkdigit):
        return True
    else:
        return False
    
    
    
print(task1_3(145765676549359))
print(task1_3('145765676549359'))
print(not task1_3(145765676549358))
print(not task1_3('1457656b6549359'))
# Out:
# True
# True
# True
# True
